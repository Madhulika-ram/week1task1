# %%
#personal_intro

# %%
name=input("What is your name?");
age=input("How old are you?");
hobby=input("What is your favourite hobby?");
skills=input("list your skills?");
# Out:
# What is your name? madhulika
# How old are you? 21
# What is your favourite hobby? reading
# list your skills? data analysis

# %%
print(f"Welcome {name} ");
print(f"You are {age} years old , Your hobby is {hobby} , and you specialize in {skills} ");
# Out:
# Welcome madhulika
# You are 21 years old , Your hobby is reading , and you specialize in data analysis
